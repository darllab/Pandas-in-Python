# %% [markdown]
# ### Coffee Chain Sales Analysis
#
# This pandas walkthrough is inspired by Alex The Analyst pandas for beginners youtube playlist.

# %% [markdown]
# ### First: Reading Files in Pandas
#
# The dataset i used is from Kaggle; you can check the dataset here https://www.kaggle.com/datasets/amruthayenikonda/coffee-chain-sales-dataset.

# %%
# Importing pandas and matplot as we needed this to our project
# I included matplot, so I can visualize this. 


import pandas as pd
import matplotlib.pyplot as plt

# %%
# There are many options for you to insert your dataset here, but i find this very easy for me. So i'll used import CSV file.

df = pd.read_csv(r"/Users/darllabulagner/Desktop/SQL THINGS/CSV FILES/Coffee_Chain_Sales .csv")

# %%
# In this section, you must see your dataset now; 

df
# Out:
#       Area Code  Cogs  DifferenceBetweenActualandTargetProfit      Date  \
# 0           303    51                                     -35   10/1/12
# 1           970    52                                     -24   10/1/12
# 2           409    43                                     -22   10/2/12
# 3           850    38                                     -15   10/3/12
# 4           562    72                                       6   10/4/12
# 5           712     0                                     -29   10/5/12
# 6           860    47                                     -29   10/6/12
# 7           918    27                                     -39   10/7/12
# 8           775    31                                     -43   10/8/12
# 9           435    40                                     -23   10/9/12
# 10          603    49                                     -27  10/10/12
# 11          603    45                                     -26  10/11/12
# ...

# %%
# As you can see, There are thousands of row, you can't view it all. To view all rows; enter this

df = pd.set_option('display.max.rows', 1063)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1061
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Area Code         1062 non-null   int64
#  1   Cogs              1062 non-null   int64
#  2   Date              1062 non-null   object
#  3   Inventory Margin  1062 non-null   int64
#  4   Margin            1062 non-null   int64
#  5   Market_size       1062 non-null   object
#  6   Market            1062 non-null   object
#  7   Product_line      1062 non-null   object
#  8   Product_type      1062 non-null   object
#  9   Product           1062 non-null   object
#  10  Profit            1062 non-null   int64
#  11  Sales             1062 non-null   int64
#  12  State             1062 non-null   object
#  13  Target_cogs       1062 non-null   int64
#  14  Target_margin     1062 non-null   int64
#  15  Target_profit     1062 non-null   int64
# ...

# %%
df.shape
# Out:
# (1062, 19)

# %%
# To view the first 10 rows of the dataset, we use "Head" to do this; inside the parenthesis is interchangeable

df.head(10)
# Out:
#    Area Code  Cogs     Date  Inventory Margin  Margin   Market_size   Market  \
# 0        303    51  10/1/12               503      71  Major Market  Central
# 1        970    52  10/1/12               405      71  Major Market  Central
# 2        409    43  10/2/12               419      64  Major Market    South
# 3        850    38  10/3/12               871      56  Major Market     East
# 4        562    72  10/4/12               650     110  Major Market     West
# 5        712     0  10/5/12               430      43  Small Market  Central
# 6        860    47  10/6/12               375      64  Small Market     East
# 7        918    27  10/7/12               859      39  Small Market    South
# 8        775    31  10/8/12              1000      37  Small Market     West
# 9        435    40  10/9/12               881      59  Small Market     West
#
#   Product_line Product_type            Product  Profit  Sales        State  \
# ...

# %%
# To view the last 10 rows of the dataset, we use "Tail" to do this; inside the parenthesis is interchangeable


df.tail(10)
# Out:
#       Area Code  Cogs     Date  Inventory Margin  Margin   Market_size Market  \
# 1052        253   115  8/18/15              1166     174  Small Market   West
# 1053        702   224  8/19/15              1191     310  Small Market   West
# 1054        503    81  8/20/15               551     104  Small Market   West
# 1055        775   127  8/21/15               830     185  Small Market   West
# 1056        775   247  8/22/15              1744     329  Small Market   West
# 1057        775   250  8/23/15              1820     251  Small Market   West
# 1058        971    88  8/24/15               817     133  Small Market   West
# 1059        775   294  8/25/15              8252    -294  Small Market   West
# 1060        503   134  8/26/15               690     186  Small Market   West
# 1061        435    20  8/27/15               218      25  Small Market   West
#
#      Product_line Product_type     Product  Profit  Sales       State  \
# ...

# %%
df['State']
# Out:
# 0            Colorado
# 1            Colorado
# 2               Texas
# 3             Florida
# 4          California
# 5                Iowa
# 6         Connecticut
# 7            Oklahoma
# 8              Nevada
# 9                Utah
# 10      New Hampshire
# 11      New Hampshire
# 12      New Hampshire
# 13          Louisiana
# 14             Nevada
# 15             Oregon
# 16           Missouri
# 17          Wisconsin
# 18               Utah
# 19         Washington
# 20        Connecticut
# 21             Oregon
# 22             Oregon
# 23              Texas
# 24              Texas
# 25           Colorado
# 26      Massachusetts
# 27            Florida
# 28              Texas
# 29           Colorado
# 30           Illinois
# 31           Colorado
# 32      Massachusetts
# 33           Missouri
# 34          Louisiana
# 35           Oklahoma
# 36          Louisiana
# 37          Wisconsin
# 38      New Hampshire
# 39      New Hampshire
# 40      New Hampshire
# ...
