# %% [markdown]
# ## Data Cleaning in Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/Users/darllabulagner/Desktop/SQL THINGS/CSV FILES/Coffee_Chain_Sales .csv")
df
# Out:
#       Area Code  Cogs  DifferenceBetweenActualandTargetProfit     Date  \
# 0           303    51                                     -35  10/1/12
# 1           970    52                                     -24  10/1/12
# 2           409    43                                     -22  10/2/12
# 3           850    38                                     -15  10/3/12
# 4           562    72                                       6  10/4/12
# ...         ...   ...                                     ...      ...
# 1057        775   250                                     133  8/23/15
# 1058        971    88                                      48  8/24/15
# 1059        775   294                                    -285  8/25/15
# 1060        503   134                                      80  8/26/15
# 1061        435    20                                     -22  8/27/15
#
#       Inventory Margin  Margin   Market_size   Market Product_line  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#       Area Code  Cogs     Date  Inventory Margin  Margin   Market_size  \
# 0           303    51  10/1/12               503      71  Major Market
# 1           970    52  10/1/12               405      71  Major Market
# 2           409    43  10/2/12               419      64  Major Market
# 3           850    38  10/3/12               871      56  Major Market
# 4           562    72  10/4/12               650     110  Major Market
# ...         ...   ...      ...               ...     ...           ...
# 1057        775   250  8/23/15              1820     251  Small Market
# 1058        971    88  8/24/15               817     133  Small Market
# 1059        775   294  8/25/15              8252    -294  Small Market
# 1060        503   134  8/26/15               690     186  Small Market
# 1061        435    20  8/27/15               218      25  Small Market
#
#        Market Product_line Product_type     Product  Profit  Sales  \
# ...

# %%
df = df.drop(columns = "Cogs")
df
# Out:
#       Area Code     Date  Inventory Margin  Margin   Market_size   Market  \
# 0           303  10/1/12               503      71  Major Market  Central
# 1           970  10/1/12               405      71  Major Market  Central
# 2           409  10/2/12               419      64  Major Market    South
# 3           850  10/3/12               871      56  Major Market     East
# 4           562  10/4/12               650     110  Major Market     West
# ...         ...      ...               ...     ...           ...      ...
# 1057        775  8/23/15              1820     251  Small Market     West
# 1058        971  8/24/15               817     133  Small Market     West
# 1059        775  8/25/15              8252    -294  Small Market     West
# 1060        503  8/26/15               690     186  Small Market     West
# 1061        435  8/27/15               218      25  Small Market     West
#
#      Product_line Product_type     Product  Profit  Sales       State  \
# ...

# %%
df.columns
# Out:
# Index(['Area Code', 'Date', 'Inventory Margin', 'Margin', 'Market_size',
#        'Market', 'Product_line', 'Product_type', 'Product', 'Profit', 'Sales',
#        'State', 'Target_cogs', 'Target_margin', 'Target_profit',
#        'Target_sales ', 'Total_expenses', 'Type'],
#       dtype='object')

# %%
df = df.reset_index(drop=True)
df
# Out:
#       Area Code     Date  Inventory Margin  Margin   Market_size   Market  \
# 0           303  10/1/12               503      71  Major Market  Central
# 1           970  10/1/12               405      71  Major Market  Central
# 2           409  10/2/12               419      64  Major Market    South
# 3           850  10/3/12               871      56  Major Market     East
# 4           562  10/4/12               650     110  Major Market     West
# ...         ...      ...               ...     ...           ...      ...
# 1057        775  8/23/15              1820     251  Small Market     West
# 1058        971  8/24/15               817     133  Small Market     West
# 1059        775  8/25/15              8252    -294  Small Market     West
# 1060        503  8/26/15               690     186  Small Market     West
# 1061        435  8/27/15               218      25  Small Market     West
#
#      Product_line Product_type     Product  Profit  Sales       State  \
# ...
