# %% [markdown]
# ### Group By and Aggregating

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/Users/darllabulagner/Desktop/SQL THINGS/CSV FILES/Coffee_Chain_Sales .csv")
df
# Out:
#       Area Code  Cogs  DifferenceBetweenActualandTargetProfit     Date  \
# 0           303    51                                     -35  10/1/12
# 1           970    52                                     -24  10/1/12
# 2           409    43                                     -22  10/2/12
# 3           850    38                                     -15  10/3/12
# 4           562    72                                       6  10/4/12
# ...         ...   ...                                     ...      ...
# 1057        775   250                                     133  8/23/15
# 1058        971    88                                      48  8/24/15
# 1059        775   294                                    -285  8/25/15
# 1060        503   134                                      80  8/26/15
# 1061        435    20                                     -22  8/27/15
#
#       Inventory Margin  Margin   Market_size   Market Product_line  \
# ...

# %%
group_by_frame = df.groupby('Product_type')

# %%
group_by_frame.mean()
# Out:
# /var/folders/b_/_sfp4nb54gd8t83zrwvftj100000gn/T/ipykernel_4944/4024548864.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_by_frame.mean()
#                Area Code       Cogs  DifferenceBetweenActualandTargetProfit  \
# Product_type
# Coffee        604.719697  82.606061                               -9.905303
# Espresso      565.761905  80.761905                               -5.850340
# Herbal Tea    592.659091  86.310606                                7.219697
# Tea           587.433333  79.875000                               11.833333
#
#               Inventory Margin      Margin     Profit       Sales  \
# Product_type
# Coffee              830.553030  109.477273  66.231061  198.382576
# Espresso            663.129252  103.700680  60.816327  190.520408
# ...

# %%
df.groupby('Product_type').mean()
# Out:
# /var/folders/b_/_sfp4nb54gd8t83zrwvftj100000gn/T/ipykernel_4944/2750969375.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_type').mean()
#                Area Code       Cogs  DifferenceBetweenActualandTargetProfit  \
# Product_type
# Coffee        604.719697  82.606061                               -9.905303
# Espresso      565.761905  80.761905                               -5.850340
# Herbal Tea    592.659091  86.310606                                7.219697
# Tea           587.433333  79.875000                               11.833333
#
#               Inventory Margin      Margin     Profit       Sales  \
# Product_type
# Coffee              830.553030  109.477273  66.231061  198.382576
# Espresso            663.129252  103.700680  60.816327  190.520408
# ...

# %%
df.groupby('Product_type').count()
# Out:
#               Area Code  Cogs  DifferenceBetweenActualandTargetProfit  Date  \
# Product_type
# Coffee              264   264                                     264   264
# Espresso            294   294                                     294   294
# Herbal Tea          264   264                                     264   264
# Tea                 240   240                                     240   240
#
#               Inventory Margin  Margin  Market_size  Market  Product_line  \
# Product_type
# Coffee                     264     264          264     264           264
# Espresso                   294     294          294     294           294
# Herbal Tea                 264     264          264     264           264
# Tea                        240     240          240     240           240
#
#               Product  Profit  Sales  State  Target_cogs  Target_margin  \
# Product_type
# Coffee            264     264    264    264          264            264
# ...

# %%
df.groupby('Product_type').sum()
# Out:
# /var/folders/b_/_sfp4nb54gd8t83zrwvftj100000gn/T/ipykernel_4944/1729267967.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Product_type').sum()
#               Area Code   Cogs  DifferenceBetweenActualandTargetProfit  \
# Product_type
# Coffee           159646  21808                                   -2615
# Espresso         166334  23744                                   -1720
# Herbal Tea       156462  22786                                    1906
# Tea              140984  19170                                    2840
#
#               Inventory Margin  Margin  Profit  Sales  Target_cogs  \
# Product_type
# Coffee                  219266   28902   17485  52373        22540
# Espresso                194960   30488   17880  56013        22380
# ...

# %%
df.groupby('Product_type').agg({'Profit': ['mean','max','count','sum'], 'Sales':['mean','max','count','sum'] })
# Out:
#                  Profit                         Sales
#                    mean  max count    sum        mean  max count    sum
# Product_type
# Coffee        66.231061  579   264  17485  198.382576  745   264  52373
# Espresso      60.816327  646   294  17880  190.520408  815   294  56013
# Herbal Tea    60.250000  459   264  15906  195.776515  796   264  51685
# Tea           54.333333  332   240  13040  178.433333  697   240  42824

# %%
df.groupby('Product_type').describe()
# Out:
#              Area Code                                                       \
#                  count        mean         std    min    25%    50%     75%
# Product_type
# Coffee           264.0  604.719697  226.411897  203.0  435.0  603.0  777.75
# Espresso         294.0  565.761905  232.654934  203.0  405.0  515.0  774.00
# Herbal Tea       264.0  592.659091  221.083603  203.0  425.0  576.5  773.00
# Tea              240.0  587.433333  218.740737  203.0  435.0  603.0  720.00
#
#                       Cogs             ... Target_sales          \
#                 max  count       mean  ...           75%    max
# Product_type                           ...
# Coffee        985.0  264.0  82.606061  ...         230.0  960.0
# Espresso      985.0  294.0  80.761905  ...         217.5  890.0
# Herbal Tea    985.0  264.0  86.310606  ...         210.0  540.0
# Tea           978.0  240.0  79.875000  ...         150.0  540.0
#
# ...
